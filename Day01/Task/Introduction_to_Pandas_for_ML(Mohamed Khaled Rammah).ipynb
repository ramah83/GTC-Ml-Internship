# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="
#         background: linear-gradient(135deg, #2f0000ff, #690202ff);
#         color: white;
#         padding: 15px 30px;
#         border-radius: 500px;
#         font-family: 'Segoe UI', Arial, sans-serif;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.3);
#         display: inline-block;
#     ">
#        GTC Task Day 1
#     </h1>
# </div>

# %% [markdown]
# <h4 style="color:#6c0e0eff">1. Importing Essential Python Libraries for Data Analysis and Visualization</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# <h4 style="color:#6c0e0eff">2. Loading the Iris Dataset into a Pandas DataFrame</h4>

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()
df = pd.DataFrame(data=iris_data['data'], columns=iris_data['feature_names'])

print("Type of the object:", type(df))
print("")
print("Shape of the DataFrame (Rows, Columns):", df.shape)
# Out:
# Type of the object: <class 'pandas.core.frame.DataFrame'>
#
# Shape of the DataFrame (Rows, Columns): (150, 4)

# %% [markdown]
# <h4 style="color:#6c0e0eff">3. Displaying the First Five Rows of the DataFrame</h4>

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# <h4 style="color:#6c0e0eff">4. Displaying the Last Five Rows of the DataFrame</h4>

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %% [markdown]
# <h4 style="color:#6c0e0eff">5. Displaying the DataFrame Information</h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# <h4 style="color:#6c0e0eff">6. Generating Descriptive Statistics of the DataFrame</h4>

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# <h4 style="color:#6c0e0eff">7. Selecting a Single Column from the DataFrame and Displaying the First Ten Rows of the DataFrame </h4>

# %%
sepal_lengths = df['sepal length (cm)']
print("Type of the selected column:", type(sepal_lengths))
print("First 10 values:")
print(sepal_lengths.head(10))
# Out:
# Type of the selected column: <class 'pandas.core.series.Series'>
# First 10 values:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# Name: sepal length (cm), dtype: float64

# %% [markdown]
# <h4 style="color:#6c0e0eff">8. Selecting Multiple Columns from the DataFrame and Displaying the First Five Rows of the DataFrame </h4>

# %%
sepal_data = df[['sepal length (cm)', 'sepal width (cm)']]
sepal_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %% [markdown]
# <h4 style="color:#6c0e0eff">9. Visualizing the Distribution of Sepal Lengths with a Histogram</h4>

# %%
import matplotlib.pyplot as plt
plt.hist(df['sepal length (cm)'], color='skyblue', edgecolor='black', bins=15)
plt.title('Distribution of Sepal Lengths')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <h4 style="color:#6c0e0eff">10. Visualizing the Distribution of Sepal Lengths with Seaborn Histogram and KDE</h4>

# %%
import seaborn as sns
plt.figure(figsize=(8, 5)) 
sns.histplot(df['sepal length (cm)'], kde=True, color='skyblue', bins=15)
plt.title('Distribution of Sepal Lengths')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <h4 style="color:#6c0e0eff">11. Visualizing Feature Correlations with a Heatmap</h4>

# %%
plt.figure(figsize=(8, 5)) 
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', cbar=False)
plt.title('Correlation Heatmap',y=1.05)
plt.show()

# %% [markdown]
# <h4 style="color:#6c0e0eff">12. Comparing Feature Distributions by Species with Boxplots</h4>

# %%
if 'species' not in df.columns:
    df['species'] = pd.Categorical.from_codes(iris_data.target, iris_data.target_names)
fig, axes = plt.subplots(2, 2, figsize=(10,8))
features = iris_data.feature_names
for ax, feat in zip(axes.ravel(), features):
    sns.boxplot(data=df, x='species', y=feat, ax=ax)
    ax.set_title(f'Boxplot of {feat} by Species')
plt.tight_layout()
plt.show()
